# %% [markdown]
# # Real time face recognizition application using deep neural network
#
#
# Below is the implementation of face detector and recognizer which can identify the face of the person showing on a web cam. We'll be implementing it Keras framework.
#
# The deep neural nework we'll be using here is based on [FaceNet](https://arxiv.org/pdf/1503.03832.pdf), which was published by Google in 2015 and achieved 99.57% accuracy on a popular face recognition dataset named “Labeled Faces in thae Wild(LFW)". You can find its open-source Keras version [here](https://github.com/iwantooxxoox/Keras-OpenFace) and Tensorflow version [here](https://github.com/davidsandberg/facenet), and play around to build your own models.

# %% [markdown]
# # Import libraries

# %%
import numpy as np
from numpy import genfromtxt
import pandas as pd
import os
import glob
import cv2
from mtcnn.mtcnn import MTCNN

import utils
#keras imported in utils.py file
# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=np.nan)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # How to let computers tell whether two pictures are the same person?
#
# Looking at the two photos below with our naked eyes, we can easily tell it is the same person, although the hairstyle, dressing and distance from the camera are different. But how can we let computers tell whether it is the same person or not?
#
# ![1](pictures/yifei.jpg)
#
# Notice when computers 'see' pictures, a RGB picture will be 'seen' as values with RGB three channels at each pixel of the picture. If it is a pixel_size*pixel_size RGB picture, it will be a (pixel_size, pixel_size, 3) matrix.
#
# Then, how to let computers tell whether two matrices represent the same person? At first, we might think of reshaping the (pixel_size, pixel_size, 3) matrix into a 1-dimensional vector and verify whether they are the same person based on the distance between them. However, the time when she took different pictures, she might be dressing in different clothes, wearing different accessories, standing at different distances away from the camera, etc. All these possibilities will significantly mislead the computer's judgements.
#
# Based on this, a direct comparation of corresponding 1-d vectors of two pictures is not an ideal strategy. Instead, we'll approach this problem by encoding the input picture into a 128-dimentional embedding by passing this picture through a deep neural network, and use the 128-dimentional embedding as the representaion of each picture. The model architecture is shown below. If the distance between two 128-d vectors is larger than the customized threshold, then these two pictures are not the same person, vice versa. We'll talk about the triplet loss function in later chapter, first, let's implement the deep neural network.
# ![2](pictures/model.png)

# %% [markdown]
# # Deep neural network--Facenet
#
# Notice the input data shape is (96, 96, 3), which is 96*96 pixel RGB(3 channels) picture; after driving through this Inception-blocks model, the last layer (which is the output) is a fully connected layer with 128 neurons. The output 128-dimension vector extracts the important features of the input facial picture and will be as the representaion of input picture.

# %%
#import facenet model
#see inception_blocks.py for model implementation
from utils import LRN2D
import utils
from inception_blocks import *

#show the architecture of the network
model = faceRecoModel((96, 96, 3))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_70 (ZeroPadding2 (None, 102, 102, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_70[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 48, 48, 64)   0           bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_71 (ZeroPadding2 (None, 50, 50, 64)   0           activation_112[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 24, 24, 64)   0           zero_padding2d_71[0][0]
# __________________________________________________________________________________________________
# lrn_1 (Lambda)                  (None, 24, 24, 64)   0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 24, 24, 64)   4160        lrn_1[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 24, 24, 64)   256         conv2[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 24, 24, 64)   0           bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_72 (ZeroPadding2 (None, 26, 26, 64)   0           activation_113[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 24, 24, 192)  110784      zero_padding2d_72[0][0]
# __________________________________________________________________________________________________
# bn3 (BatchNormalization)        (None, 24, 24, 192)  768         conv3[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 24, 24, 192)  0           bn3[0][0]
# __________________________________________________________________________________________________
# lrn_2 (Lambda)                  (None, 24, 24, 192)  0           activation_114[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_73 (ZeroPadding2 (None, 26, 26, 192)  0           lrn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 12, 12, 192)  0           zero_padding2d_73[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv1 (Conv2D) (None, 12, 12, 96)   18528       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv1 (Conv2D) (None, 12, 12, 16)   3088        max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn1 (BatchNorm (None, 12, 12, 16)   64          inception_3a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 12, 12, 96)   0           inception_3a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 12, 12, 16)   0           inception_3a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 5, 5, 192)    0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_74 (ZeroPadding2 (None, 14, 14, 96)   0           activation_115[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_75 (ZeroPadding2 (None, 16, 16, 16)   0           activation_117[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_conv (Conv2D) (None, 5, 5, 32)     6176        max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_74[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv2 (Conv2D) (None, 12, 12, 32)   12832       zero_padding2d_75[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_bn (BatchNorm (None, 5, 5, 32)     128         inception_3a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_conv (Conv2D)  (None, 12, 12, 64)   12352       max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn2 (BatchNorm (None, 12, 12, 32)   128         inception_3a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 5, 5, 32)     0           inception_3a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 12, 12, 128)  0           inception_3a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 12, 12, 32)   0           inception_3a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_76 (ZeroPadding2 (None, 12, 12, 32)   0           activation_119[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 12, 12, 64)   0           inception_3a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 12, 12, 256)  0           activation_116[0][0]
#                                                                  activation_118[0][0]
#                                                                  zero_padding2d_76[0][0]
#                                                                  activation_120[0][0]
# __________________________________________________________________________________________________
# power2_3b (Lambda)              (None, 12, 12, 256)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv1 (Conv2D) (None, 12, 12, 96)   24672       concatenate_22[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv1 (Conv2D) (None, 12, 12, 32)   8224        concatenate_22[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 4, 4, 256)    0           power2_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3b_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_3b (Lambda)               (None, 4, 4, 256)    0           average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 12, 12, 96)   0           inception_3b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 12, 12, 32)   0           inception_3b_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_3b (Lambda)                (None, 4, 4, 256)    0           mult9_3b[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_77 (ZeroPadding2 (None, 14, 14, 96)   0           activation_121[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_78 (ZeroPadding2 (None, 16, 16, 32)   0           activation_123[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_conv (Conv2D) (None, 4, 4, 64)     16448       sqrt_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_77[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv2 (Conv2D) (None, 12, 12, 64)   51264       zero_padding2d_78[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_bn (BatchNorm (None, 4, 4, 64)     256         inception_3b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_conv (Conv2D)  (None, 12, 12, 64)   16448       concatenate_22[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn2 (BatchNorm (None, 12, 12, 64)   256         inception_3b_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 4, 4, 64)     0           inception_3b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 12, 12, 128)  0           inception_3b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 12, 12, 64)   0           inception_3b_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_79 (ZeroPadding2 (None, 12, 12, 64)   0           activation_125[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 12, 12, 64)   0           inception_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 12, 12, 320)  0           activation_122[0][0]
#                                                                  activation_124[0][0]
#                                                                  zero_padding2d_79[0][0]
#                                                                  activation_126[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv1 (Conv2D) (None, 12, 12, 128)  41088       concatenate_23[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv1 (Conv2D) (None, 12, 12, 32)   10272       concatenate_23[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn1 (BatchNorm (None, 12, 12, 128)  512         inception_3c_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3c_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 12, 12, 128)  0           inception_3c_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 12, 12, 32)   0           inception_3c_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_80 (ZeroPadding2 (None, 14, 14, 128)  0           activation_127[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_81 (ZeroPadding2 (None, 16, 16, 32)   0           activation_129[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv2 (Conv2D) (None, 6, 6, 256)    295168      zero_padding2d_80[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_81[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn2 (BatchNorm (None, 6, 6, 256)    1024        inception_3c_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_3c_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 5, 5, 320)    0           concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 6, 6, 256)    0           inception_3c_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 6, 6, 64)     0           inception_3c_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_82 (ZeroPadding2 (None, 6, 6, 320)    0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 6, 6, 640)    0           activation_128[0][0]
#                                                                  activation_130[0][0]
#                                                                  zero_padding2d_82[0][0]
# __________________________________________________________________________________________________
# power2_4a (Lambda)              (None, 6, 6, 640)    0           concatenate_24[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv1 (Conv2D) (None, 6, 6, 96)     61536       concatenate_24[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv1 (Conv2D) (None, 6, 6, 32)     20512       concatenate_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_14 (AveragePo (None, 2, 2, 640)    0           power2_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn1 (BatchNorm (None, 6, 6, 96)     384         inception_4a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn1 (BatchNorm (None, 6, 6, 32)     128         inception_4a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_4a (Lambda)               (None, 2, 2, 640)    0           average_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 6, 6, 96)     0           inception_4a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 6, 6, 32)     0           inception_4a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_4a (Lambda)                (None, 2, 2, 640)    0           mult9_4a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_83 (ZeroPadding2 (None, 8, 8, 96)     0           activation_131[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_84 (ZeroPadding2 (None, 10, 10, 32)   0           activation_133[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_conv (Conv2D) (None, 2, 2, 128)    82048       sqrt_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv2 (Conv2D) (None, 6, 6, 192)    166080      zero_padding2d_83[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_84[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_bn (BatchNorm (None, 2, 2, 128)    512         inception_4a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_conv (Conv2D)  (None, 6, 6, 256)    164096      concatenate_24[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn2 (BatchNorm (None, 6, 6, 192)    768         inception_4a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_4a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 2, 2, 128)    0           inception_4a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 6, 6, 256)    1024        inception_4a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 6, 6, 192)    0           inception_4a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 6, 6, 64)     0           inception_4a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_85 (ZeroPadding2 (None, 6, 6, 128)    0           activation_135[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 6, 6, 256)    0           inception_4a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 6, 6, 640)    0           activation_132[0][0]
#                                                                  activation_134[0][0]
#                                                                  zero_padding2d_85[0][0]
#                                                                  activation_136[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv1 (Conv2D) (None, 6, 6, 160)    102560      concatenate_25[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv1 (Conv2D) (None, 6, 6, 64)     41024       concatenate_25[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn1 (BatchNorm (None, 6, 6, 160)    640         inception_4e_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn1 (BatchNorm (None, 6, 6, 64)     256         inception_4e_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 6, 6, 160)    0           inception_4e_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 6, 6, 64)     0           inception_4e_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_86 (ZeroPadding2 (None, 8, 8, 160)    0           activation_137[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_87 (ZeroPadding2 (None, 10, 10, 64)   0           activation_139[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv2 (Conv2D) (None, 3, 3, 256)    368896      zero_padding2d_86[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv2 (Conv2D) (None, 3, 3, 128)    204928      zero_padding2d_87[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn2 (BatchNorm (None, 3, 3, 256)    1024        inception_4e_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn2 (BatchNorm (None, 3, 3, 128)    512         inception_4e_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 2, 2, 640)    0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 3, 3, 256)    0           inception_4e_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 3, 3, 128)    0           inception_4e_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_88 (ZeroPadding2 (None, 3, 3, 640)    0           max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 3, 3, 1024)   0           activation_138[0][0]
#                                                                  activation_140[0][0]
#                                                                  zero_padding2d_88[0][0]
# __________________________________________________________________________________________________
# power2_5a (Lambda)              (None, 3, 3, 1024)   0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv1 (Conv2D) (None, 3, 3, 96)     98400       concatenate_26[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_15 (AveragePo (None, 1, 1, 1024)   0           power2_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_5a (Lambda)               (None, 1, 1, 1024)   0           average_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 3, 3, 96)     0           inception_5a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_5a (Lambda)                (None, 1, 1, 1024)   0           mult9_5a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_89 (ZeroPadding2 (None, 5, 5, 96)     0           activation_141[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_conv (Conv2D) (None, 1, 1, 96)     98400       sqrt_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_89[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_conv (Conv2D)  (None, 3, 3, 256)    262400      concatenate_26[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 1, 1, 96)     0           inception_5a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 3, 3, 384)    0           inception_5a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_90 (ZeroPadding2 (None, 3, 3, 96)     0           activation_143[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 3, 3, 256)    0           inception_5a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 3, 3, 736)    0           activation_142[0][0]
#                                                                  zero_padding2d_90[0][0]
#                                                                  activation_144[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv1 (Conv2D) (None, 3, 3, 96)     70752       concatenate_27[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 3, 3, 96)     0           inception_5b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 1, 1, 736)    0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_91 (ZeroPadding2 (None, 5, 5, 96)     0           activation_145[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_conv (Conv2D) (None, 1, 1, 96)     70752       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_91[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_conv (Conv2D)  (None, 3, 3, 256)    188672      concatenate_27[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 1, 1, 96)     0           inception_5b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 3, 3, 384)    0           inception_5b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_92 (ZeroPadding2 (None, 3, 3, 96)     0           activation_147[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 3, 3, 256)    0           inception_5b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 3, 3, 736)    0           activation_146[0][0]
#                                                                  zero_padding2d_92[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_16 (AveragePo (None, 1, 1, 736)    0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 736)          0           average_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, 128)          94336       flatten_4[0][0]
# __________________________________________________________________________________________________
# norm_layer (Lambda)             (None, 128)          0           dense_layer[0][0]
# ==================================================================================================
# Total params: 3,743,280
# Trainable params: 3,733,968
# Non-trainable params: 9,312
# __________________________________________________________________________________________________

# %% [markdown]
# # Triplet loss function
#
# The FaceNet model converts input images into 128-d embeddings to represent the image. Then parameters are trained by minimizing the triplet loss. The Triplet Loss minimizes the distance between an anchor and a positive, both of which have the same identity, and maximizes the distance between the anchor and a negative of a different identity. As shown below:
#
# ![3](pictures/triplet.png)
#
# The training process requires GPU and high amount of training data, you can also transfer learning and fine tune the weights. But here we'll be loading previously trained weights, which are available at [here](https://github.com/iwantooxxoox/Keras-OpenFace)  in the "weights" folder and they are also provided in this source.

# %%
# load weights(this process will take a few minutes)
import utils
weights = utils.weights
weights_dict = utils.load_weights()

for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## Capture, crop, align and resize identity face image in real time using OpenCV
# In this section, we'll be using OpenCV (make sure you've installed it) to open a web camera, detect and outine the face area using a blue rectangle and then capture 15 face images of the person that is in front of the camera.
#
# These cropped face snapshots are stored in **"images"** folder with the name NameHere_1 to NameHere_15. Select onely one well captured face image from these 15 images for each person. Rename it with the name of person and delete rest of them. Repeat this process by different people, with each person only keeps one picture in this folder. Later in this program, when a person shows up in front of the camera, it will calculate its distance from each stored pictures and return the most likely one's name.

# %%
cap = cv2.VideoCapture(0)
detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    # capture frame by frame
    ret, img = cap.read()
    
    # detect the face, you can change the scaleFactor according to your case
    faces = detector.detectMultiScale(img, scaleFactor= 1.5, minNeighbors= 5)
    for (x,y,w,h) in faces:
        
        # outline the face area by a blue rectangle
        cv2.rectangle(img, (x,y), (x+w,y+h), (255,0,0),2)     
        count += 1
        # save the cropped face image into the datasets folder
        cv2.imwrite("images/NameHere_" + str(count) + ".jpg", img[y:y+h,x:x+w])
        cv2.imshow('image', img)
    # Press 'ESC' for exiting video
    k = cv2.waitKey(200) & 0xff 
    if k == 27:
        break
    elif count >= 8: 
         break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Or detect face by Multi-task CNN
# Besides using OpenCV to detect face, we can also use Dlib or deep learning Multi-task CNN. Here we show how to use MTCNN to detect the face from an image. After running this section, you may go to "pictures" folder to check t

# %%
from mtcnn.mtcnn import MTCNN

image= cv2.imread('pictures/yifei.jpg')
detector1= MTCNN()
result=detector1.detect_faces(image)
print(result)

count=0
for person in result:
            bounding_box = person['box']
            x=bounding_box[0]
            y=bounding_box[1]
            w=bounding_box[2]
            h=bounding_box[3]
            keypoints = person['keypoints']
            
            cv2.rectangle(image, (x, y), (x+w, y+h), (255,0,255), 2)
            cv2.circle(image,(keypoints['left_eye']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['right_eye']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['nose']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['mouth_left']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['mouth_right']), 2, (0,155,255), 2)
            cv2.imwrite("pictures/" + str(count)+ "_detected.jpg", image)
            cv2.imwrite("pictures/" + str(count)+ ".jpg", image[y:y+h,x:x+w])
            count +=1
# Out:
# [{'box': [112, 7, 71, 96], 'confidence': 0.9997676014900208, 'keypoints': {'left_eye': (130, 45), 'right_eye': (163, 42), 'nose': (147, 63), 'mouth_left': (136, 82), 'mouth_right': (162, 79)}}, {'box': [331, 41, 72, 98], 'confidence': 0.9918006062507629, 'keypoints': {'left_eye': (353, 82), 'right_eye': (387, 79), 'nose': (374, 103), 'mouth_left': (360, 117), 'mouth_right': (387, 114)}}]

# %% [markdown]
# # Steps to recognize faces:
# #First, encode one single image into embeddings
# #Second, build a database containing embeddings for all images by passing all images through the weighted Facenet model
# #Third, identify images by using the embeddings(find the minimum L2 euclidean distance between embeddings)

# %%
#First, encode one single image into embeddings
def image_to_embedding(image, model):
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding



#Second, build a database containing embeddings for all images
def build_database_dict():
    database = {}   
    for file in glob.glob("/Users/Olivia/Documents/ML/Face-recognition-using-deep-learning-master/images/*"):
        database_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        database[database_name] = image_to_embedding(image_file, model)
    return database


#Third, identify images by using the embeddings(find the minimum L2 euclidean distance between embeddings)
def recognize_face(face_image, database, model):
    
    embedding = image_to_embedding(face_image, model)   
    minimum_distance = 200
    name = None    
    # Loop over  names and encodings.
    for (database_name, database_embedding) in database.items():
            
        euclidean_distance = np.linalg.norm(embedding-database_embedding)
        print('Euclidean distance from %s is %s' %(database_name, euclidean_distance))
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = database_name
    
    if minimum_distance < 0.8:
        return str(name)+str('  ')+str(round(minimum_distance,14))
    else:
        return 'Unknown'

# %% [markdown]
# # Try an image

# %%
database= build_database_dict()
image= cv2.imread('images/Obama.jpg')
recognize_face(image, database, model)
# Out:
# Euclidean distance from Jennifer is 1.2726864
# Euclidean distance from Joe is 0.9621877
# Euclidean distance from Meng is 1.0812176
# Euclidean distance from Obama is 0.0
# 'Obama  0.0'

# %% [markdown]
# # Recognize faces in real time using webcam

# %%
cv2.namedWindow("Face Recognizer")
vc = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX
detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
      
while True:
    ret, frame = vc.read()
    height, width, channels = frame.shape
     
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector.detectMultiScale(gray, 1.3, 5)

    # loop through all the faces detected 
    for (x, y, w, h) in faces:          
        face_image = frame[max(0, y):min(height, y+h), max(0, x):min(width, x+w)]    
        identity = recognize_face(face_image, database, model)          
        if identity is not None:
            img = cv2.rectangle(frame,(x, y),(x+w, y+h),(255,0,0),2)
            cv2.putText(frame, str(identity), (x+5,y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,255), 2)
        
    key = cv2.waitKey(100)
    cv2.imshow("Face Recognizer", frame)
    
    if key == 27: # exit on ESC
        break
vc.release()
cv2.destroyAllWindows()
# Out:
# Euclidean distance from Jennifer is 0.83125496
# Euclidean distance from Joe is 1.0655255
# Euclidean distance from Meng is 0.6985585
# Euclidean distance from Obama is 1.1785898
# Euclidean distance from Jennifer is 1.0161357
# Euclidean distance from Joe is 1.2249637
# Euclidean distance from Meng is 0.9209807
# Euclidean distance from Obama is 1.4129999
# Euclidean distance from Jennifer is 1.0432053
# Euclidean distance from Joe is 1.031677
# Euclidean distance from Meng is 0.7130936
# Euclidean distance from Obama is 1.2910315
# Euclidean distance from Jennifer is 0.9109769
# Euclidean distance from Joe is 1.1065911
# Euclidean distance from Meng is 0.6033511
# Euclidean distance from Obama is 1.267821
# Euclidean distance from Jennifer is 0.7227077
# Euclidean distance from Joe is 1.1103779
# Euclidean distance from Meng is 0.77546626
# Euclidean distance from Obama is 1.3206162
# Euclidean distance from Jennifer is 1.1842653
# Euclidean distance from Joe is 1.1953577
# Euclidean distance from Meng is 1.0247298
# Euclidean distance from Obama is 1.0696076
# Euclidean distance from Jennifer is 1.103484
# Euclidean distance from Joe is 1.1380379
# Euclidean distance from Meng is 0.8582084
# Euclidean distance from Obama is 1.088146
# Euclidean distance from Jennifer is 0.75567263
# Euclidean distance from Joe is 1.0714968
# Euclidean distance from Meng is 0.7168913
# Euclidean distance from Obama is 1.2940218
# Euclidean distance from Jennifer is 0.9276392
# Euclidean distance from Joe is 1.0285292
# Euclidean distance from Meng is 0.44401887
# Euclidean distance from Obama is 1.2369184
# Euclidean distance from Jennifer is 0.88915247
# Euclidean distance from Joe is 1.0414151
# Euclidean distance from Meng is 0.66893184
# Euclidean distance from Obama is 1.2201889
# Euclidean distance from Jennifer is 1.1174264
# Euclidean distance from Joe is 1.1625737
# Euclidean distance from Meng is 0.6119185
# Euclidean distance from Obama is 1.2676351
# Euclidean distance from Jennifer is 1.095487
# Euclidean distance from Joe is 1.0398918
# Euclidean distance from Meng is 1.2132592
# Euclidean distance from Obama is 1.0771129
# Euclidean distance from Jennifer is 1.1195647
# Euclidean distance from Joe is 1.1360224
# Euclidean distance from Meng is 0.5946022
# Euclidean distance from Obama is 1.2641199
# Euclidean distance from Jennifer is 0.95836514
# Euclidean distance from Joe is 1.1130458
# Euclidean distance from Meng is 0.5591197
# Euclidean distance from Obama is 1.2891635
# Euclidean distance from Jennifer is 1.1067487
# Euclidean distance from Joe is 1.1332668
# Euclidean distance from Meng is 0.5974556
# Euclidean distance from Obama is 1.2359173
# Euclidean distance from Jennifer is 1.0877413
# Euclidean distance from Joe is 1.1393163
# Euclidean distance from Meng is 0.6305724
# Euclidean distance from Obama is 1.285688
# Euclidean distance from Jennifer is 1.0322239
# Euclidean distance from Joe is 1.1488088
# Euclidean distance from Meng is 0.6008672
# Euclidean distance from Obama is 1.3054254
# Euclidean distance from Jennifer is 1.0131052
# Euclidean distance from Joe is 1.1626318
# Euclidean distance from Meng is 0.59002256
# Euclidean distance from Obama is 1.2955778
# Euclidean distance from Jennifer is 0.93409824
# Euclidean distance from Joe is 1.1173619
# Euclidean distance from Meng is 0.58249414
# Euclidean distance from Obama is 1.3334277
# Euclidean distance from Jennifer is 1.069441
# Euclidean distance from Joe is 1.146784
# Euclidean distance from Meng is 0.5793244
# Euclidean distance from Obama is 1.2560815
# Euclidean distance from Jennifer is 1.0445243
# Euclidean distance from Joe is 1.1170639
# Euclidean distance from Meng is 0.56569976
# Euclidean distance from Obama is 1.253838
# Euclidean distance from Jennifer is 1.0775119
# Euclidean distance from Joe is 1.156277
# Euclidean distance from Meng is 0.5811987
# Euclidean distance from Obama is 1.2580923
# Euclidean distance from Jennifer is 1.0878276
# Euclidean distance from Joe is 1.1471915
# Euclidean distance from Meng is 0.60094965
# Euclidean distance from Obama is 1.253235
# Euclidean distance from Jennifer is 0.9982349
# Euclidean distance from Joe is 1.1238863
# Euclidean distance from Meng is 0.5717943
# Euclidean distance from Obama is 1.2576236
# Euclidean distance from Jennifer is 1.043419
# Euclidean distance from Joe is 1.1422297
# Euclidean distance from Meng is 0.57506025
# Euclidean distance from Obama is 1.259898
# Euclidean distance from Jennifer is 1.0261006
# Euclidean distance from Joe is 1.1046581
# Euclidean distance from Meng is 0.5938049
# Euclidean distance from Obama is 1.2504541
# Euclidean distance from Jennifer is 1.057768
# Euclidean distance from Joe is 1.0839252
# Euclidean distance from Meng is 0.627203
# Euclidean distance from Obama is 1.264756
# Euclidean distance from Jennifer is 1.0479074
# Euclidean distance from Joe is 1.0983942
# Euclidean distance from Meng is 0.60536635
# Euclidean distance from Obama is 1.2773833
# Euclidean distance from Jennifer is 1.0334603
# Euclidean distance from Joe is 1.105229
# Euclidean distance from Meng is 0.6145476
# Euclidean distance from Obama is 1.2763122
# Euclidean distance from Jennifer is 0.96238005
# Euclidean distance from Joe is 1.0987736
# Euclidean distance from Meng is 0.6560497
# Euclidean distance from Obama is 1.3268547
# Euclidean distance from Jennifer is 1.0179074
# Euclidean distance from Joe is 1.1329982
# Euclidean distance from Meng is 0.6576025
# Euclidean distance from Obama is 1.2588782
# Euclidean distance from Jennifer is 1.0339895
# Euclidean distance from Joe is 1.1082734
# Euclidean distance from Meng is 0.6076834
# Euclidean distance from Obama is 1.2313584
# Euclidean distance from Jennifer is 1.254629
# Euclidean distance from Joe is 1.1012917
# Euclidean distance from Meng is 1.350562
# Euclidean distance from Obama is 1.2038256
# Euclidean distance from Jennifer is 1.0433547
# Euclidean distance from Joe is 1.0935858
# Euclidean distance from Meng is 0.6555064
# Euclidean distance from Obama is 1.2583325
# Euclidean distance from Jennifer is 1.0008799
# Euclidean distance from Joe is 1.0617226
# Euclidean distance from Meng is 0.6355254
# Euclidean distance from Obama is 1.2342391
# Euclidean distance from Jennifer is 0.9324735
# Euclidean distance from Joe is 1.0410023
# Euclidean distance from Meng is 0.5985598
# Euclidean distance from Obama is 1.1579397
# Euclidean distance from Jennifer is 0.96434486
# Euclidean distance from Joe is 1.0720264
# Euclidean distance from Meng is 0.5576681
# Euclidean distance from Obama is 1.2093565
# Euclidean distance from Jennifer is 0.9771172
# Euclidean distance from Joe is 1.0042803
# Euclidean distance from Meng is 0.5272246
# Euclidean distance from Obama is 1.2520326
# Euclidean distance from Jennifer is 1.2096102
# Euclidean distance from Joe is 1.1901524
# Euclidean distance from Meng is 0.81127745
# Euclidean distance from Obama is 1.3199244
# Euclidean distance from Jennifer is 1.1901302
# Euclidean distance from Joe is 1.1224108
# Euclidean distance from Meng is 0.8073866
# Euclidean distance from Obama is 1.2150773
# Euclidean distance from Jennifer is 1.2471516
# Euclidean distance from Joe is 1.1719366
# Euclidean distance from Meng is 0.7838476
# Euclidean distance from Obama is 1.1853051
# Euclidean distance from Jennifer is 0.95775527
# Euclidean distance from Joe is 1.0766151
# Euclidean distance from Meng is 0.7386984
# Euclidean distance from Obama is 1.2910936
# Euclidean distance from Jennifer is 0.8408668
# Euclidean distance from Joe is 0.93829435
# Euclidean distance from Meng is 0.70822597
# Euclidean distance from Obama is 1.1557105
# Euclidean distance from Jennifer is 0.9568599
# Euclidean distance from Joe is 0.9936677
# Euclidean distance from Meng is 0.7209346
# Euclidean distance from Obama is 1.1742364
# Euclidean distance from Jennifer is 0.9333673
# Euclidean distance from Joe is 1.0408585
# Euclidean distance from Meng is 0.755724
# Euclidean distance from Obama is 1.1117531
# Euclidean distance from Jennifer is 0.90392774
# Euclidean distance from Joe is 1.0250442
# Euclidean distance from Meng is 0.7814302
# Euclidean distance from Obama is 1.1090367
# Euclidean distance from Jennifer is 0.93843323
# Euclidean distance from Joe is 0.8755307
# Euclidean distance from Meng is 0.7109702
# Euclidean distance from Obama is 1.0007496
# Euclidean distance from Jennifer is 0.9673504
# Euclidean distance from Joe is 0.92176235
# Euclidean distance from Meng is 0.6169175
# Euclidean distance from Obama is 0.9898554
# Euclidean distance from Jennifer is 0.90092766
# Euclidean distance from Joe is 0.938595
# Euclidean distance from Meng is 0.6673306
# Euclidean distance from Obama is 1.0537764
# Euclidean distance from Jennifer is 0.93875504
# Euclidean distance from Joe is 1.015461
# Euclidean distance from Meng is 0.6817943
# Euclidean distance from Obama is 1.1793675
# Euclidean distance from Jennifer is 0.8956259
# Euclidean distance from Joe is 0.95937705
# Euclidean distance from Meng is 0.6615768
# Euclidean distance from Obama is 1.1332229
# Euclidean distance from Jennifer is 1.011641
# Euclidean distance from Joe is 0.8590611
# Euclidean distance from Meng is 0.78178096
# Euclidean distance from Obama is 1.1200665
# Euclidean distance from Jennifer is 1.054867
# Euclidean distance from Joe is 0.7902088
# Euclidean distance from Meng is 0.764065
# Euclidean distance from Obama is 0.8887481
# Euclidean distance from Jennifer is 0.90788025
# Euclidean distance from Joe is 0.92861605
# Euclidean distance from Meng is 0.6216641
# Euclidean distance from Obama is 1.1222074
# Euclidean distance from Jennifer is 0.8967658
# Euclidean distance from Joe is 0.9060387
# Euclidean distance from Meng is 0.62717134
# Euclidean distance from Obama is 1.075803
# Euclidean distance from Jennifer is 0.79286826
# Euclidean distance from Joe is 0.77219814
# Euclidean distance from Meng is 0.65344787
# Euclidean distance from Obama is 0.9333605
