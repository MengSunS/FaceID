# %% [markdown]
# # Real time face recognizition application using deep neural network
#
#
# Below is the implementation of face detector and recognizer which can identify the face of the person showing on a web cam. We'll be implementing it Keras framework.
#
# The deep neural nework we'll be using here is based on [FaceNet](https://arxiv.org/pdf/1503.03832.pdf), which was published by Google in 2015 and achieved 99.57% accuracy on a popular face recognition dataset named “Labeled Faces in thae Wild(LFW)". You can find its open-source Keras version [here](https://github.com/iwantooxxoox/Keras-OpenFace) and Tensorflow version [here](https://github.com/davidsandberg/facenet), and play around to build your own models.

# %% [markdown]
# # Import libraries

# %%
import numpy as np
from numpy import genfromtxt
import pandas as pd
import os
import glob
import cv2
from mtcnn.mtcnn import MTCNN

import fr_utils
#keras imported in fr_utils.py file
# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=np.nan)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # How to let computers tell whether two pictures are the same person?
#
# Looking at the two photos below with our naked eyes, we can easily tell it is the same person, although the hairstyle, dressing and distance from the camera are different. But how can we let computers tell whether it is the same person or not?
#
# ![1](pictures/yifei.jpg)
#
# Notice when computers 'see' pictures, a RGB picture will be 'seen' as values with RGB three channels at each pixel of the picture. If it is a pixel_size*pixel_size RGB picture, it will be a (pixel_size, pixel_size, 3) matrix.
#
# Then, how to let computers tell whether two matrices represent the same person? At first, we might think of reshaping the (pixel_size, pixel_size, 3) matrix into a 1-dimensional vector and verify whether they are the same person based on the distance between them. However, the time when she took different pictures, she might be dressing in different clothes, wearing different accessories, standing at different distances away from the camera, etc. All these possibilities will significantly mislead the computer's judgements.
#
# Based on this, a direct comparation of corresponding 1-d vectors of two pictures is not an ideal strategy. Instead, we'll approach this problem by encoding the input picture into a 128-dimentional embedding by passing this picture through a deep neural network, and use the 128-dimentional embedding as the representaion of each picture. The model architecture is shown below. If the distance between two 128-d vectors is larger than the customized threshold, then these two pictures are not the same person, vice versa. We'll talk about the triplet loss function in later chapter, first, let's implement the deep neural network.
# ![2](pictures/model.png)

# %% [markdown]
# # Deep neural network--Facenet
#
# Notice the input data shape is (96, 96, 3), which is 96*96 pixel RGB(3 channels) picture; after driving through this Inception-blocks model, the last layer (which is the output) is a fully connected layer with 128 neurons. The output 128-dimension vector extracts the important features of the input facial picture and will be as the representaion of input picture.

# %%
#import facenet model
from inception_blocks_v2 import *

#show the architecture of the network
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 102, 102, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 64)   0           bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 50, 50, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# lrn_1 (Lambda)                  (None, 24, 24, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 24, 24, 64)   4160        lrn_1[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 24, 24, 64)   256         conv2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 64)   0           bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 26, 26, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 24, 24, 192)  110784      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# bn3 (BatchNormalization)        (None, 24, 24, 192)  768         conv3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 24, 192)  0           bn3[0][0]
# __________________________________________________________________________________________________
# lrn_2 (Lambda)                  (None, 24, 24, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 26, 26, 192)  0           lrn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv1 (Conv2D) (None, 12, 12, 96)   18528       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv1 (Conv2D) (None, 12, 12, 16)   3088        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn1 (BatchNorm (None, 12, 12, 16)   64          inception_3a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 12, 96)   0           inception_3a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 12, 12, 16)   0           inception_3a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 5, 192)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 14, 14, 96)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 16)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_conv (Conv2D) (None, 5, 5, 32)     6176        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv2 (Conv2D) (None, 12, 12, 32)   12832       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_bn (BatchNorm (None, 5, 5, 32)     128         inception_3a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_conv (Conv2D)  (None, 12, 12, 64)   12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn2 (BatchNorm (None, 12, 12, 32)   128         inception_3a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5, 5, 32)     0           inception_3a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 12, 128)  0           inception_3a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 12, 12, 32)   0           inception_3a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 12, 12, 32)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 12, 64)   0           inception_3a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  zero_padding2d_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# power2_3b (Lambda)              (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv1 (Conv2D) (None, 12, 12, 96)   24672       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv1 (Conv2D) (None, 12, 12, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 256)    0           power2_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3b_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_3b (Lambda)               (None, 4, 4, 256)    0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 96)   0           inception_3b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 12, 32)   0           inception_3b_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_3b (Lambda)                (None, 4, 4, 256)    0           mult9_3b[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 14, 14, 96)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 16, 16, 32)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_conv (Conv2D) (None, 4, 4, 64)     16448       sqrt_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv2 (Conv2D) (None, 12, 12, 64)   51264       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_bn (BatchNorm (None, 4, 4, 64)     256         inception_3b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_conv (Conv2D)  (None, 12, 12, 64)   16448       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn2 (BatchNorm (None, 12, 12, 64)   256         inception_3b_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 64)     0           inception_3b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 12, 128)  0           inception_3b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 12, 64)   0           inception_3b_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 12, 12, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 12, 12, 64)   0           inception_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 320)  0           activation_11[0][0]
#                                                                  activation_13[0][0]
#                                                                  zero_padding2d_10[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv1 (Conv2D) (None, 12, 12, 128)  41088       concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv1 (Conv2D) (None, 12, 12, 32)   10272       concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn1 (BatchNorm (None, 12, 12, 128)  512         inception_3c_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3c_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           inception_3c_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 32)   0           inception_3c_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 14, 14, 128)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 32)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv2 (Conv2D) (None, 6, 6, 256)    295168      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn2 (BatchNorm (None, 6, 6, 256)    1024        inception_3c_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_3c_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 5, 320)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 6, 6, 256)    0           inception_3c_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 6, 6, 64)     0           inception_3c_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 6, 6, 320)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 6, 6, 640)    0           activation_17[0][0]
#                                                                  activation_19[0][0]
#                                                                  zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# power2_4a (Lambda)              (None, 6, 6, 640)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv1 (Conv2D) (None, 6, 6, 96)     61536       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv1 (Conv2D) (None, 6, 6, 32)     20512       concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 640)    0           power2_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn1 (BatchNorm (None, 6, 6, 96)     384         inception_4a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn1 (BatchNorm (None, 6, 6, 32)     128         inception_4a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_4a (Lambda)               (None, 2, 2, 640)    0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 6, 6, 96)     0           inception_4a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 32)     0           inception_4a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_4a (Lambda)                (None, 2, 2, 640)    0           mult9_4a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 8, 8, 96)     0           activation_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 10, 10, 32)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_conv (Conv2D) (None, 2, 2, 128)    82048       sqrt_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv2 (Conv2D) (None, 6, 6, 192)    166080      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_bn (BatchNorm (None, 2, 2, 128)    512         inception_4a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_conv (Conv2D)  (None, 6, 6, 256)    164096      concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn2 (BatchNorm (None, 6, 6, 192)    768         inception_4a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_4a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 128)    0           inception_4a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 6, 6, 256)    1024        inception_4a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 192)    0           inception_4a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 64)     0           inception_4a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 6, 6, 128)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           inception_4a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 6, 6, 640)    0           activation_21[0][0]
#                                                                  activation_23[0][0]
#                                                                  zero_padding2d_16[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv1 (Conv2D) (None, 6, 6, 160)    102560      concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv1 (Conv2D) (None, 6, 6, 64)     41024       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn1 (BatchNorm (None, 6, 6, 160)    640         inception_4e_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn1 (BatchNorm (None, 6, 6, 64)     256         inception_4e_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 6, 6, 160)    0           inception_4e_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 6, 6, 64)     0           inception_4e_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 8, 8, 160)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 10, 10, 64)   0           activation_28[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv2 (Conv2D) (None, 3, 3, 256)    368896      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv2 (Conv2D) (None, 3, 3, 128)    204928      zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn2 (BatchNorm (None, 3, 3, 256)    1024        inception_4e_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn2 (BatchNorm (None, 3, 3, 128)    512         inception_4e_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 640)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 256)    0           inception_4e_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 3, 3, 128)    0           inception_4e_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 3, 3, 640)    0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 3, 1024)   0           activation_27[0][0]
#                                                                  activation_29[0][0]
#                                                                  zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# power2_5a (Lambda)              (None, 3, 3, 1024)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv1 (Conv2D) (None, 3, 3, 96)     98400       concatenate_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 1024)   0           power2_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_5a (Lambda)               (None, 1, 1, 1024)   0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 3, 3, 96)     0           inception_5a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_5a (Lambda)                (None, 1, 1, 1024)   0           mult9_5a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 5, 5, 96)     0           activation_30[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_conv (Conv2D) (None, 1, 1, 96)     98400       sqrt_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_conv (Conv2D)  (None, 3, 3, 256)    262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 1, 96)     0           inception_5a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 3, 3, 384)    0           inception_5a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 3, 3, 96)     0           activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 3, 3, 256)    0           inception_5a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3, 3, 736)    0           activation_31[0][0]
#                                                                  zero_padding2d_21[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv1 (Conv2D) (None, 3, 3, 96)     70752       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 3, 3, 96)     0           inception_5b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 736)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 5, 5, 96)     0           activation_34[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_conv (Conv2D) (None, 1, 1, 96)     70752       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_conv (Conv2D)  (None, 3, 3, 256)    188672      concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1, 1, 96)     0           inception_5b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 3, 3, 384)    0           inception_5b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 3, 3, 96)     0           activation_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 3, 3, 256)    0           inception_5b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 3, 3, 736)    0           activation_35[0][0]
#                                                                  zero_padding2d_23[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 736)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 736)          0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, 128)          94336       flatten_1[0][0]
# __________________________________________________________________________________________________
# norm_layer (Lambda)             (None, 128)          0           dense_layer[0][0]
# ==================================================================================================
# Total params: 3,743,280
# Trainable params: 3,733,968
# Non-trainable params: 9,312
# __________________________________________________________________________________________________

# %% [markdown]
# # Triplet loss function
#
# The FaceNet model converts input images into 128-d embeddings to represent the image. Then parameters are trained by minimizing the triplet loss. The Triplet Loss minimizes the distance between an anchor and a positive, both of which have the same identity, and maximizes the distance between the anchor and a negative of a different identity. As shown below:
#
# ![3](pictures/triplet.png)
#
# The training process requires GPU and high amount of training data, you can also transfer learning and fine tune the weights. But here we'll be loading previously trained weights, which are available at [here](https://github.com/iwantooxxoox/Keras-OpenFace)  in the "weights" folder and they are also provided in this source.

# %%
# load weights(this process will take a few minutes)
import fr_utils
weights = fr_utils.WEIGHTS
weights_dict = fr_utils.load_weights()

for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## Capture, crop, align and resize identity face image in real time using OpenCV
# In this section, we'll be using OpenCV (make sure you've installed it) to open a web camera, detect and outine the face area using a blue rectangle and then capture 15 face images of the person that is in front of the camera.
#
# These cropped face snapshots are stored in **"images"** folder with the name NameHere_1 to NameHere_15. Select onely one well captured face image from these 15 images for each person. Rename it with the name of person and delete rest of them. Repeat this process by different people, with each person only keeps one picture in this folder. Later in this program, when a person shows up in front of the camera, it will calculate its distance from each stored pictures and return the most likely one's name.

# %%
cap = cv2.VideoCapture(0)
detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    # capture frame by frame
    ret, img = cap.read()
    
    # detect the face, you can change the scaleFactor according to your case
    faces = detector.detectMultiScale(img, scaleFactor= 1.5, minNeighbors= 5)
    for (x,y,w,h) in faces:
        
        # outline the face area by a blue rectangle
        cv2.rectangle(img, (x,y), (x+w,y+h), (255,0,0),2)     
        count += 1
        # save the cropped face image into the datasets folder
        cv2.imwrite("images/NameHere_" + str(count) + ".jpg", img[y:y+h,x:x+w])
        cv2.imshow('image', img)
    # Press 'ESC' for exiting video
    k = cv2.waitKey(200) & 0xff 
    if k == 27:
        break
    elif count >= 8: 
         break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Or detect face by Multi-task CNN
# Besides using OpenCV to detect face, we can also use Dlib or deep learning Multi-task CNN. Here we show how to use MTCNN to detect the face from an image. After running this section, you may go to "pictures" folder to check t

# %%
from mtcnn.mtcnn import MTCNN

image= cv2.imread('pictures/yifei.jpg')
detector1= MTCNN()
result=detector1.detect_faces(image)
print(result)

count=0
for person in result:
            bounding_box = person['box']
            x=bounding_box[0]
            y=bounding_box[1]
            w=bounding_box[2]
            h=bounding_box[3]
            keypoints = person['keypoints']
            
            cv2.rectangle(image, (x, y), (x+w, y+h), (255,0,255), 2)
            cv2.circle(image,(keypoints['left_eye']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['right_eye']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['nose']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['mouth_left']), 2, (0,155,255), 2)
            cv2.circle(image,(keypoints['mouth_right']), 2, (0,155,255), 2)
            cv2.imwrite("pictures/" + str(count)+ "_detected.jpg", image)
            cv2.imwrite("pictures/" + str(count)+ ".jpg", image[y:y+h,x:x+w])
            count +=1
# Out:
# [{'box': [112, 7, 71, 96], 'confidence': 0.9997676014900208, 'keypoints': {'left_eye': (130, 45), 'right_eye': (163, 42), 'nose': (147, 63), 'mouth_left': (136, 82), 'mouth_right': (162, 79)}}, {'box': [331, 41, 72, 98], 'confidence': 0.9918006062507629, 'keypoints': {'left_eye': (353, 82), 'right_eye': (387, 79), 'nose': (374, 103), 'mouth_left': (360, 117), 'mouth_right': (387, 114)}}]

# %% [markdown]
# # Steps to recognize faces:
# #First, encode one single image into embeddings
# #Second, build a database containing embeddings for all images by passing all images through the weighted Facenet model
# #Third, identify images by using the embeddings(find the minimum L2 euclidean distance between embeddings)

# %%
#First, encode one single image into embeddings
def image_to_embedding(image, model):
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding



#Second, build a database containing embeddings for all images
def build_database_dict():
    database = {}   
    for file in glob.glob("/Users/Olivia/Documents/ML/Face-recognition-using-deep-learning-master/images/*"):
        database_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        database[database_name] = image_to_embedding(image_file, model)
    return database


#Third, identify images by using the embeddings(find the minimum L2 euclidean distance between embeddings)
def recognize_face(face_image, database, model):
    
    embedding = image_to_embedding(face_image, model)   
    minimum_distance = 200
    name = None    
    # Loop over  names and encodings.
    for (database_name, database_embedding) in database.items():
            
        euclidean_distance = np.linalg.norm(embedding-database_embedding)
        print('Euclidean distance from %s is %s' %(database_name, euclidean_distance))
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = database_name
    
    if minimum_distance < 0.8:
        return str(name)+str('  ')+str(round(minimum_distance,14))
    else:
        return 'Unknown'

# %% [markdown]
# # Try an image

# %%
database= build_database_dict()
image= cv2.imread('images/Obama.jpg')
recognize_face(image, database, model)
# Out:
# Euclidean distance from Jennifer is 1.2726864
# Euclidean distance from Joe is 0.9621877
# Euclidean distance from Meng is 1.0812176
# Euclidean distance from Obama is 0.0
# 'Obama  0.0'

# %% [markdown]
# # Recognize faces in real time using webcam

# %%
cv2.namedWindow("Face Recognizer")
vc = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_SIMPLEX
detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
      
while True:
    ret, frame = vc.read()
    height, width, channels = frame.shape
     
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector.detectMultiScale(gray, 1.3, 5)

    # loop through all the faces detected 
    for (x, y, w, h) in faces:          
        face_image = frame[max(0, y):min(height, y+h), max(0, x):min(width, x+w)]    
        identity = recognize_face(face_image, input_embeddings, model)          
        if identity is not None:
            img = cv2.rectangle(frame,(x, y),(x+w, y+h),(255,0,0),2)
            cv2.putText(frame, str(identity), (x+5,y-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,255), 2)
        
    key = cv2.waitKey(100)
    cv2.imshow("Face Recognizer", frame)
    
    if key == 27: # exit on ESC
        break
vc.release()
cv2.destroyAllWindows()
# Out:
# Euclidean distance from Jennifer is 1.1636072
# Euclidean distance from Joe is 0.99348277
# Euclidean distance from Kunal is 1.3410087
# Euclidean distance from Meng is 1.1328946
# Euclidean distance from Obama is 1.2766345
# Euclidean distance from Sumantra is 0.9365692
# Euclidean distance from Jennifer is 1.1028574
# Euclidean distance from Joe is 1.1334138
# Euclidean distance from Kunal is 1.2826748
# Euclidean distance from Meng is 0.8025866
# Euclidean distance from Obama is 1.3182212
# Euclidean distance from Sumantra is 1.2306647
# Euclidean distance from Jennifer is 0.99225825
# Euclidean distance from Joe is 0.9792911
# Euclidean distance from Kunal is 1.146365
# Euclidean distance from Meng is 0.63666
# Euclidean distance from Obama is 1.2010647
# Euclidean distance from Sumantra is 1.0860212
# Euclidean distance from Jennifer is 0.8120448
# Euclidean distance from Joe is 1.0149534
# Euclidean distance from Kunal is 0.88661957
# Euclidean distance from Meng is 0.6359426
# Euclidean distance from Obama is 1.1323072
# Euclidean distance from Sumantra is 1.055557
# Euclidean distance from Jennifer is 0.9135987
# Euclidean distance from Joe is 1.1550931
# Euclidean distance from Kunal is 0.95653075
# Euclidean distance from Meng is 0.654015
# Euclidean distance from Obama is 1.1047335
# Euclidean distance from Sumantra is 1.1140456
# Euclidean distance from Jennifer is 0.8350197
# Euclidean distance from Joe is 1.1560831
# Euclidean distance from Kunal is 0.9248743
# Euclidean distance from Meng is 0.6785517
# Euclidean distance from Obama is 1.1386831
# Euclidean distance from Sumantra is 1.1286875
# Euclidean distance from Jennifer is 0.965753
# Euclidean distance from Joe is 1.1351955
# Euclidean distance from Kunal is 1.0090506
# Euclidean distance from Meng is 0.5106709
# Euclidean distance from Obama is 1.0763993
# Euclidean distance from Sumantra is 1.1184503
# Euclidean distance from Jennifer is 0.96070546
# Euclidean distance from Joe is 1.1295929
# Euclidean distance from Kunal is 1.0873593
# Euclidean distance from Meng is 0.44836932
# Euclidean distance from Obama is 1.1089503
# Euclidean distance from Sumantra is 1.1078666
# Euclidean distance from Jennifer is 0.96567315
# Euclidean distance from Joe is 1.1656238
# Euclidean distance from Kunal is 1.0282477
# Euclidean distance from Meng is 0.5783798
# Euclidean distance from Obama is 1.1318289
# Euclidean distance from Sumantra is 1.1466379
# Euclidean distance from Jennifer is 0.9136316
# Euclidean distance from Joe is 1.1680275
# Euclidean distance from Kunal is 1.0711828
# Euclidean distance from Meng is 0.661155
# Euclidean distance from Obama is 1.185821
# Euclidean distance from Sumantra is 1.1677059
# Euclidean distance from Jennifer is 0.8508453
# Euclidean distance from Joe is 1.0575786
# Euclidean distance from Kunal is 1.097152
# Euclidean distance from Meng is 0.60082686
# Euclidean distance from Obama is 1.2355917
# Euclidean distance from Sumantra is 1.074217
# Euclidean distance from Jennifer is 0.8736766
# Euclidean distance from Joe is 1.0808678
# Euclidean distance from Kunal is 1.1518873
# Euclidean distance from Meng is 0.44581127
# Euclidean distance from Obama is 1.2317891
# Euclidean distance from Sumantra is 1.0592194
# Euclidean distance from Jennifer is 0.9743901
# Euclidean distance from Joe is 1.1105807
# Euclidean distance from Kunal is 1.1278678
# Euclidean distance from Meng is 0.45401183
# Euclidean distance from Obama is 1.1802119
# Euclidean distance from Sumantra is 1.0476642
# Euclidean distance from Jennifer is 1.0297742
# Euclidean distance from Joe is 1.0534817
# Euclidean distance from Kunal is 1.1051853
# Euclidean distance from Meng is 0.48987153
# Euclidean distance from Obama is 1.0949297
# Euclidean distance from Sumantra is 1.0281826
# Euclidean distance from Jennifer is 1.093584
# Euclidean distance from Joe is 1.1294718
# Euclidean distance from Kunal is 1.2357681
# Euclidean distance from Meng is 0.5382374
# Euclidean distance from Obama is 1.1841983
# Euclidean distance from Sumantra is 1.0586741
# Euclidean distance from Jennifer is 1.2119627
# Euclidean distance from Joe is 1.1449122
# Euclidean distance from Kunal is 1.2278692
# Euclidean distance from Meng is 0.6682448
# Euclidean distance from Obama is 1.1430448
# Euclidean distance from Sumantra is 1.0790166
# Euclidean distance from Jennifer is 1.1803682
# Euclidean distance from Joe is 1.1276093
# Euclidean distance from Kunal is 1.3004009
# Euclidean distance from Meng is 0.6090786
# Euclidean distance from Obama is 1.2233087
# Euclidean distance from Sumantra is 1.0890261
# Euclidean distance from Jennifer is 1.2420497
# Euclidean distance from Joe is 1.2169617
# Euclidean distance from Kunal is 1.3292203
# Euclidean distance from Meng is 0.714761
# Euclidean distance from Obama is 1.231961
# Euclidean distance from Sumantra is 1.1541814
# Euclidean distance from Jennifer is 1.2154757
# Euclidean distance from Joe is 1.2107042
# Euclidean distance from Kunal is 1.287335
# Euclidean distance from Meng is 0.66029435
# Euclidean distance from Obama is 1.2119464
# Euclidean distance from Sumantra is 1.1459752
# Euclidean distance from Jennifer is 1.2514235
# Euclidean distance from Joe is 1.2046156
# Euclidean distance from Kunal is 1.2754015
# Euclidean distance from Meng is 0.68057144
# Euclidean distance from Obama is 1.1916392
# Euclidean distance from Sumantra is 1.1194735
# Euclidean distance from Jennifer is 1.1147292
# Euclidean distance from Joe is 1.1751634
# Euclidean distance from Kunal is 1.2214003
# Euclidean distance from Meng is 0.58483064
# Euclidean distance from Obama is 1.1985852
# Euclidean distance from Sumantra is 1.0960692
# Euclidean distance from Jennifer is 1.1053216
# Euclidean distance from Joe is 1.0878756
# Euclidean distance from Kunal is 1.1278208
# Euclidean distance from Meng is 0.55810964
# Euclidean distance from Obama is 1.0844183
# Euclidean distance from Sumantra is 0.9746265
# Euclidean distance from Jennifer is 1.2092085
# Euclidean distance from Joe is 1.1342713
# Euclidean distance from Kunal is 1.0656395
# Euclidean distance from Meng is 0.8592062
# Euclidean distance from Obama is 0.97783697
# Euclidean distance from Sumantra is 1.012663
# Euclidean distance from Jennifer is 1.039473
# Euclidean distance from Joe is 0.81457305
# Euclidean distance from Kunal is 0.953048
# Euclidean distance from Meng is 0.6255637
# Euclidean distance from Obama is 0.91646206
# Euclidean distance from Sumantra is 0.8784591
# Euclidean distance from Jennifer is 0.90492123
# Euclidean distance from Joe is 1.0612236
# Euclidean distance from Kunal is 1.1163043
# Euclidean distance from Meng is 0.5857403
# Euclidean distance from Obama is 1.1249764
# Euclidean distance from Sumantra is 0.9649698
# Euclidean distance from Jennifer is 1.021218
# Euclidean distance from Joe is 0.99906254
# Euclidean distance from Kunal is 1.0688441
# Euclidean distance from Meng is 0.7791856
# Euclidean distance from Obama is 1.1540303
# Euclidean distance from Sumantra is 1.1512299
# Euclidean distance from Jennifer is 0.9739721
# Euclidean distance from Joe is 1.0633193
# Euclidean distance from Kunal is 1.1208755
# Euclidean distance from Meng is 0.87674385
# Euclidean distance from Obama is 1.3089684
# Euclidean distance from Sumantra is 1.2008196
# Euclidean distance from Jennifer is 1.0347337
# Euclidean distance from Joe is 1.0880854
# Euclidean distance from Kunal is 1.2271391
# Euclidean distance from Meng is 0.7913349
# Euclidean distance from Obama is 1.2804452
# Euclidean distance from Sumantra is 1.1853902
# Euclidean distance from Jennifer is 0.795292
# Euclidean distance from Joe is 0.9632602
# Euclidean distance from Kunal is 1.0931997
# Euclidean distance from Meng is 0.73971593
# Euclidean distance from Obama is 1.2108462
# Euclidean distance from Sumantra is 0.9762337
# Euclidean distance from Jennifer is 0.8509863
# Euclidean distance from Joe is 0.9383317
# Euclidean distance from Kunal is 1.0536871
# Euclidean distance from Meng is 0.7446802
# Euclidean distance from Obama is 1.177676
# Euclidean distance from Sumantra is 0.9843835
# Euclidean distance from Jennifer is 1.0220826
# Euclidean distance from Joe is 1.1368948
# Euclidean distance from Kunal is 1.1511288
# Euclidean distance from Meng is 0.8417309
# Euclidean distance from Obama is 1.2795013
# Euclidean distance from Sumantra is 1.2400733
